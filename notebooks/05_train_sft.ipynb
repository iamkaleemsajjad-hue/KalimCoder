# %% [markdown]
# # 05 — Train SFT (Supervised Fine-Tuning)
#
# Fine-tune Qwen3-8B on coding data using **QLoRA** with LLaMA Factory.
#
# ## Config
# See `../configs/qwen3_sft.yaml` and `../configs/qlora.yaml`

# %%
import subprocess, os

# Launch training via LLaMA Factory
config_path = '../configs/qwen3_sft.yaml'

cmd = [
    'llamafactory-cli', 'train', config_path
]

print(f'Running: {" ".join(cmd)}')
# Uncomment to run:
# result = subprocess.run(cmd, check=True)

# %%
# Alternative: use TRL SFTTrainer directly
from trl import SFTTrainer, SFTConfig
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from peft import LoraConfig, get_peft_model
from datasets import load_dataset
import torch

print('Imports OK — fill in model path and dataset before running.')
