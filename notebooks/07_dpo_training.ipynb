# %% [markdown]
# # 07 — DPO Training (Direct Preference Optimization)
#
# Train KaleemCoder with DPO to align outputs with human preferences.
#
# ## Config
# See `../configs/dpo.yaml`

# %%
from trl import DPOTrainer, DPOConfig
from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import PeftModel
import torch

print('DPO training scaffold ready. Configure paths and run.')

# %%
# Load SFT model as the reference model
SFT_MODEL_PATH = '../adapters/kaleemcoder-sft'
DPO_DATA_PATH  = '../datasets/processed/dpo_pairs.jsonl'

# TODO: Load preference dataset (chosen / rejected pairs)
# TODO: Configure DPOConfig
# TODO: Run DPOTrainer
print('Fill in paths and launch.')
